# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
csv_filepath = r"C:\Users\henry\Desktop\henry\AMZN_data.csv"

# %%
df=pd.read_csv (r"C:\Users\henry\Desktop\henry\AMZN_data.csv")

# %%
df.head(10)
# Out:
#               open    high      low   close   volume  Name
# date
# 2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN
# 2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN
# 2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN
# 2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN
# 2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN
# 2013-02-15  267.63  268.92  263.110  265.09  3979832  AMZN
# 2013-02-19  265.91  270.11  264.500  269.75  2853752  AMZN
# 2013-02-20  270.20  274.30  266.371  266.41  3528862  AMZN
# 2013-02-21  265.12  269.48  263.250  265.94  3637396  AMZN
# 2013-02-22  266.62  267.11  261.610  265.42  3123402  AMZN

# %%
df.tail(5)
# Out:
#             date     open     high      low    close    volume  Name
# 1254  2018-02-01  1445.00  1459.88  1385.14  1390.00   9113808  AMZN
# 1255  2018-02-02  1477.39  1498.00  1414.00  1429.95  11125722  AMZN
# 1256  2018-02-05  1402.62  1458.98  1320.72  1390.00  11494985  AMZN
# 1257  2018-02-06  1361.46  1443.99  1351.79  1442.84  11066819  AMZN
# 1258  2018-02-07  1449.00  1460.99  1415.15  1416.78   7162741  AMZN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   object
#  1   open    1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   close   1259 non-null   float64
#  5   volume  1259 non-null   int64
#  6   Name    1259 non-null   object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 69.0+ KB

# %%
df.describe()
# Out:
#               open         high          low        close        volume
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean    576.867264   582.017221   571.113517   576.880041  3.730465e+06
# std     282.500019   284.417123   280.215237   282.500395  2.166506e+06
# min     248.940000   252.930000   245.750000   248.230000  1.092970e+06
# 25%     325.870000   329.485000   322.185000   325.800000  2.511165e+06
# 50%     506.000000   512.330000   495.640000   503.820000  3.144719e+06
# 75%     777.620000   781.845000   770.720000   777.420000  4.220246e+06
# max    1477.390000  1498.000000  1450.040000  1450.890000  2.385606e+07

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Stock Prices - Closing Price over Time')
plt.grid(True)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(df['close'], model='multiplicative', period = 365)

# %%
plt.figure(figsize=(100, 300))
decomposition.plot()
plt.show()

# %%
seasonal = decomposition.seasonal

# %%
plt.figure(figsize=(10, 6))
plt.plot(df.index, seasonal)
plt.xlabel('Date')
plt.ylabel('Seasonal Component')
plt.show()
